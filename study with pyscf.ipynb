# %%
pip install pyscf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 MB 11.2 MB/s eta 0:00:00
# ...

# %%
# This is a minimal example on how to do Hartree-Fock calculations using pyscf
# you need to install pyscf first, using `pip install pyscf`
# For more examples, see https://github.com/pyscf/pyscf/tree/master/examples/scf
import pyscf

mol = pyscf.M(
    atom = 'H 0 0 0; H 0 0 1',  # in Angstrom
    basis = 'sto-3g',
    symmetry = False,
    verbose = 4
)

myhf = mol.HF()
myhf.kernel()
# Out:
# System: uname_result(system='Linux', node='2b7a28d17cfd', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Mon May 13 12:05:58 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 2
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 H      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
import matplotlib.pyplot as plt

basis = ['sto-3g', 'sto-6g', 'cc-pvdz', 'cc-pvtz', 'cc-pvqz', 'cc-pv5z']
hf_energy = []
a = 'H 0 0 0; H 0 0 1'
for b in basis:
  mol = pyscf.M(atom=a, basis=b, symmetry=False, verbose=4)
  myhf = mol.HF()

  hf_energy.append(myhf.kernel())
# Out:
# System: uname_result(system='Linux', node='2b7a28d17cfd', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Mon May 13 12:08:56 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 2
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 H      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
plt.figure()
plt.scatter(basis, hf_energy-hf_energy[-1])
plt.show()
print(basis,hf_energy)
# Out:
# ['sto-3g', 'sto-6g', 'cc-pvdz', 'cc-pvtz', 'cc-pvqz', 'cc-pv5z'] [-1.0661086493179366, -1.073582930786361, -1.1001537648784105, -1.1020623237472957, -1.1024597443439883, -1.102578036681292]

# %%
from pyscf import gto, scf

mol = gto.Mole()
mol.verbose = 5
#mol.output = 'out_h2o'
mol.atom = '''
O        0.000000    0.000000    0.117790
H        0.000000    0.755453   -0.471161
H        0.000000   -0.755453   -0.471161'''
mol.basis = 'ccpvdz'
mol.symmetry = 1
mol.build()

mf = scf.RHF(mol)
mf.kernel()
# Out:
# System: uname_result(system='Linux', node='5fedd05f6585', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Fri May 10 16:39:02 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 5
# [INPUT] max_memory = 4000
# [INPUT] num. atoms = 3
# [INPUT] num. electrons = 10
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry 1 subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 O      0.000000000000   0.000000000000   0.117790000000 AA    0.000000000000   0.000000000000   0.222590840213 Bohr   0.0
# ...

# %%
import pyscf

mol = pyscf.M(
    atom = 'O 0 0 0;He 0 0 1',  # in Angstrom
    basis = 'cc-pv5z',
    symmetry = False,
    verbose = 4
)

myhf = mol.HF()
myhf.kernel()
# Out:
# System: uname_result(system='Linux', node='5fedd05f6585', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Fri May 10 16:39:04 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 10
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 O      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
basis = ['sto-3g', 'sto-6g', 'cc-pvdz', 'cc-pvtz', 'cc-pvqz', 'cc-pv5z']
hf_energy = []
a = 'O 0 0 0;He 0 0 1'
for b in basis:
  mol = pyscf.M(atom=a, basis=b, symmetry=False, verbose=4)
  myhf = mol.HF()

  hf_energy.append(myhf.kernel())

plt.figure()
plt.scatter(basis, hf_energy)
plt.show()
print(basis,hf_energy)
# Out:
# System: uname_result(system='Linux', node='5fedd05f6585', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Fri May 10 16:39:19 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 10
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 O      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt



basis=np.linspace(1,5,20)
hf_energy = []

for b in basis:
  a = f'He 0 0 0;H 0 0 {b}'
  mol = pyscf.M(atom=a, basis='cc-pv5z', symmetry=False, verbose=4,charge=1,unit='B')
  myhf = mol.HF()

  hf_energy.append(myhf.kernel())

a = 'He 0 0 0'
mol = pyscf.M(atom=a, basis='cc-pv5z', symmetry=False, verbose=4)
myhf = mol.HF()
n=myhf.kernel()

plt.figure()
plt.scatter(basis, hf_energy-n)
plt.show()
print(basis,hf_energy)
# Out:
# System: uname_result(system='Linux', node='2b7a28d17cfd', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Mon May 13 13:04:45 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 2
# [INPUT] charge = 1
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = B
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 He     0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


basis=np.linspace(1,5,20)
hf_energy = []

for b in basis:
  a = f'N 0 0 0;N 0 0 {b}'
  mol = pyscf.M(atom=a, basis='sto-6g', symmetry=False, verbose=4,unit='AU')
  myhf = mol.HF()

  hf_energy.append(myhf.kernel())

a = 'N 0 0 0'
mol = pyscf.M(atom=a, basis='sto-6g', symmetry=False, verbose=4, spin=3)
myhf = mol.HF()
n=myhf.kernel()

plt.figure()
plt.scatter(basis, hf_energy-n)
plt.show()
print(basis,hf_energy)
# Out:
# System: uname_result(system='Linux', node='e3d999c2aa58', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Mon May 13 08:23:56 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 14
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = AU
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 N      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...

# %%
from pyscf import gto, scf
a = f'N 0 0 0;N 0 0 2'
mol = pyscf.M(atom=a, basis='sto-6g', symmetry=False, verbose=4,unit='AU')
myhf = mol.HF()

hf_energy=(myhf.kernel())
hf_es = scf.RHF(mol)
hf_es.verbose = 4
hf_es.nroots = 5
hf_es.kernel()


hf_es_energy = hf_es.e_tot

print(hf_es_energy,hf_energy)
# Out:
# System: uname_result(system='Linux', node='e3d999c2aa58', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')  Threads 2
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy 1.25.2  scipy 1.11.4
# Date: Mon May 13 08:36:43 2024
# PySCF version 2.5.0
# PySCF path  /usr/local/lib/python3.10/dist-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 14
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = AU
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 N      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# ...
